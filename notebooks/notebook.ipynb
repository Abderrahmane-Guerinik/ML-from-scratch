# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()
sys.path.append(str(project_root))

# %%
# testing the SimpleLinearRegression implplementation
import numpy as np
from mlfs.simple_linear_regression import SimpleLinearRegression

# create the dataset
X = np.random.randint(0, 20, size=10)

# lets try w=2 & b=-1
y = 2 * X - 1


model = SimpleLinearRegression()
# train the model (Gradient Descent)
model.fit(X, y, epochs=3000, patience=10)
# Out:
# Epoch 0 loss: 4.639312399999999 w: 1.556 b: 0.15
# Epoch 10 loss: 0.14563524603049519 w: 1.8865532638952618 b: 0.15693629510001172
# Epoch 20 loss: 0.1394841919943314 w: 1.8889748874846348 b: 0.13224052425716287
# Epoch 30 loss: 0.13359293403629774 w: 1.891344811254692 b: 0.1080719044641649
# Epoch 40 loss: 0.12795049940248354 w: 1.893664147022191 b: 0.08441918404959772
# Epoch 50 loss: 0.12254637878450055 w: 1.8959339746303054 b: 0.0612713507102788
# Epoch 60 loss: 0.11737050674538257 w: 1.8981553508720528 b: 0.038617627209835956
# Epoch 70 loss: 0.11241324297222113 w: 1.9003293099823222 b: 0.01644746636101004
# Epoch 80 loss: 0.10766535432061404 w: 1.902456864119393 b: -0.0052494538849357005
# Epoch 90 loss: 0.10311799761748608 w: 1.9045390038361834 b: -0.026483235243985145
# Epoch 100 loss: 0.09876270319024937 w: 1.9065766985414299 b: -0.047263763802556355
# Epoch 110 loss: 0.09459135909162837 w: 1.9085708969510302 b: -0.06760071462029452
# ...
