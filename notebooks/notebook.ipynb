# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()
sys.path.append(str(project_root))

# %%
# testing the SimpleLinearRegression implplementation
import numpy as np
from mlfs.multiple_linear_regression import MultipleLinearRegression

# create the dataset
X = np.random.uniform(low=1, high=10, size=20).reshape((10, 2))

# lets try w1 = 1 w2 = 2 b = -2
y = X[:, 0] * 1 + X[:, 1] * 2 + 1 


model = MultipleLinearRegression()
# train the model (Gradient Descent)
model.fit(X, y, epochs=100000, patience=10, alpha=0.0001)
# Out:
# Epoch 0 loss: 245.23705182759147 w: [0.01365436 0.01707636] b: 0.002201428517731955
# Epoch 10 loss: 201.99833806389222 w: [0.14296155 0.17912201] b: 0.02308684614234512
# Epoch 20 loss: 166.41470361402867 w: [0.25997487 0.32635348] b: 0.0420540749852818
# Epoch 30 loss: 137.13038232733658 w: [0.36583829 0.4601447 ] b: 0.059281100376881585
# Epoch 40 loss: 113.02973114177092 w: [0.46158953 0.581742  ] b: 0.07492937957925808
# Epoch 50 loss: 93.19470116905701 w: [0.5481699  0.69227601] b: 0.08914537671889648
# Epoch 60 loss: 76.86984120443874 w: [0.62643328 0.79277233] b: 0.10206195517194529
# Epoch 70 loss: 63.43349957051593 w: [0.69715426 0.88416137] b: 0.11379964064040159
# Epoch 80 loss: 52.374126489470285 w: [0.76103544 0.96728712] b: 0.12446776692797422
# Epoch 90 loss: 43.270773613667245 w: [0.81871419 1.04291522] b: 0.13416551530916632
# Epoch 100 loss: 35.77704734321804 w: [0.87076863 1.11174021] b: 0.14298285737344943
# ...
